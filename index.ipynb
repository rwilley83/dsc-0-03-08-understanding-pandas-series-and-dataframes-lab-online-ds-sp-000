# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
column_names = {}
for column_name in list(df.columns.values):
    column_names[column_name] = column_name.lower()
df = df.rename(columns=column_names)
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
df = df.reset_index()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
def line_count(text):
    return len(text)
    
df['Num_Lines'] = df.linename.map(line_count)
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# ...

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.lower().strip() #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'num_lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# df.date = pd.to_datetime(df.date)
df['day_of_week'] = df['date'].dt.day_name()
df.head()
# Out:
#   linename   c/a  unit       scp station division       date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  num_lines day_of_week
# 0  REGULAR  6736067  2283184          7    Saturday
# 1  REGULAR  6736087  2283188          7    Saturday
# 2  REGULAR  6736105  2283229          7    Saturday
# 3  REGULAR  6736180  2283314          7    Saturday
# 4  REGULAR  6736349  2283384          7    Saturday

# %%
days = list(df.day_of_week)
entries = list(df.entries)
day_counts = {}
for i in list(range(0, len(days))):
    day_counts[days[i]] = day_counts.get(days[i], 0) + entries[i]
day_counts

plt.figure(figsize=(12, 4))
plt.bar(day_counts.keys(), day_counts.values())
plt.title("Subway Traffic")
plt.xlabel("Day of Week")
plt.ylabel("Number of Rides")
# plt.ylim((25000, 29000))
plt.show()

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
wend_avg = (day_counts['Sunday'] + day_counts['Saturday']) / 2
weekdays = []

for key in day_counts.keys():
    if key != 'Sunday' and key != 'Saturday':
        weekdays.append(day_counts[key])
        
wday_avg = sum(weekdays) / len(weekdays)
pct_diff = round(100 * wday_avg / wend_avg - 100, 2)

print("Weekday Average:", wday_avg)
print("Weekend Average:", wend_avg)
print("Percentage Difference: " + str(pct_diff) + "%")
# Out:
# Weekday Average: 1122830850136.2
# Weekend Average: 1153983862298.0
# Percentage Difference: -2.7%

# %% [markdown]
# # Drop a couple of columns

# %%
df = df.drop(['division', 'desc'], axis=1)
df.head()
# Out:
#   linename   c/a  unit       scp station       date      time  entries  \
# 0  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  00:00:00  6736067
# 1  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  04:00:00  6736087
# 2  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  08:00:00  6736105
# 3  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  12:00:00  6736180
# 4  NQR456W  A002  R051  02-00-00   59 ST 2018-08-25  16:00:00  6736349
#
#      exits  num_lines day_of_week
# 0  2283184          7    Saturday
# 1  2283188          7    Saturday
# 2  2283229          7    Saturday
# 3  2283314          7    Saturday
# 4  2283384          7    Saturday
